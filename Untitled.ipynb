# %%
# Out:
# [16:39:22] WARNING: not removing hydrogen atom without neighbors
# [16:39:29] WARNING: not removing hydrogen atom without neighbors
# [16:39:32] WARNING: not removing hydrogen atom without neighbors
# [16:39:33] WARNING: not removing hydrogen atom without neighbors
# [16:39:35] WARNING: not removing hydrogen atom without neighbors
# [16:39:45] WARNING: not removing hydrogen atom without neighbors
# [16:39:47] WARNING: not removing hydrogen atom without neighbors
# [16:39:48] WARNING: not removing hydrogen atom without neighbors
# [16:39:49] WARNING: not removing hydrogen atom without neighbors
# [16:39:51] WARNING: not removing hydrogen atom without neighbors
# 生成 21463 个三元组 -> triplets.csv

# %%
# Out:
# 警告：chemblid 'CHEMBL5958' 的exemplar信息不完整，跳过。
# 警告：chemblid 'CHEMBL4105819' 的exemplar信息不完整，跳过。
# 警告：chemblid 'CHEMBL5019' 的exemplar信息不完整，跳过。
# 警告：chemblid 'CHEMBL3308924' 的exemplar信息不完整，跳过。
# 警告：chemblid 'CHEMBL3399913' 的exemplar信息不完整，跳过。
# 警告：chemblid 'CHEMBL2421' 的exemplar信息不完整，跳过。
# 警告：chemblid 'CHEMBL1649053' 的exemplar信息不完整，跳过。
# 警告：chemblid 'CHEMBL4523283' 的exemplar信息不完整，跳过。
# 警告：chemblid 'CHEMBL4105957' 的exemplar信息不完整，跳过。
# 警告：chemblid 'CHEMBL289' 在CSV中未找到，跳过该行。
# 警告：chemblid 'CHEMBL5995' 的exemplar信息不完整，跳过。
# 警告：chemblid 'CHEMBL5995' 的exemplar信息不完整，跳过。
# 警告：chemblid 'CHEMBL1681619' 的exemplar信息不完整，跳过。
# 警告：chemblid 'CHEMBL4523235' 的exemplar信息不完整，跳过。
# 警告：chemblid 'CHEMBL4295702' 的exemplar信息不完整，跳过。
# 警告：chemblid 'CHEMBL4741' 的exemplar信息不完整，跳过。
# 警告：chemblid 'CHEMBL4377' 的exemplar信息不完整，跳过。
# 警告：chemblid 'CHEMBL4524129' 的exemplar信息不完整，跳过。
# 警告：chemblid 'CHEMBL4866' 的exemplar信息不完整，跳过。
# 警告：chemblid 'CHEMBL2141' 的exemplar信息不完整，跳过。
# 警告：chemblid 'CHEMBL2887' 的exemplar信息不完整，跳过。
# ...
